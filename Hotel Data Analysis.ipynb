# %% [markdown]
# # Hotel Data Analysis

# %% [markdown]
# # Business Objective: The objective of the project is to analyse a hotel dataset to optimize various aspects of operations, boost revenue streams, and create a more efficient and satisfying experience for guests.

# %% [markdown]
# # Part 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hotel=pd.read_csv('Hotel Dataset.csv')
hotel
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 0     Resort Hotel            0         68               2015
# 1     Resort Hotel            0         14               2015
# 2     Resort Hotel            0         10               2015
# 3     Resort Hotel            0          9               2015
# 4     Resort Hotel            0         51               2015
# ...            ...          ...        ...                ...
# 2092    City Hotel            0         15               2017
# 2093    City Hotel            0         83               2017
# 2094    City Hotel            0        189               2017
# 2095    City Hotel            0        147               2017
# 2096    City Hotel            0        135               2017
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                  July                        27                          1
# ...

# %%
hotel.shape
# Out:
# (2097, 32)

# %%
hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0         68               2015               July
# 1  Resort Hotel            0         14               2015               July
# 2  Resort Hotel            0         10               2015               July
# 3  Resort Hotel            0          9               2015               July
# 4  Resort Hotel            0         51               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          2
# 2                        27                          3
# 3                        27                          3
# 4                        28                          6
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     4       2  ...    No Deposit
# ...

# %%
hotel.describe()
# Out:
#        is_canceled    lead_time  arrival_date_year  arrival_date_week_number  \
# count  2097.000000  2097.000000        2097.000000               2097.000000
# mean      0.238913    77.190749        2016.369099                 26.874583
# std       0.426521    82.734572           0.636185                 12.069021
# min       0.000000     0.000000        2015.000000                  1.000000
# 25%       0.000000    14.000000        2016.000000                 18.000000
# 50%       0.000000    51.000000        2016.000000                 27.000000
# 75%       0.000000   116.000000        2017.000000                 35.000000
# max       1.000000   542.000000        2017.000000                 53.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                2097.000000              2097.000000
# mean                   15.388174                 0.855031
# std                     8.780726                 0.928742
# ...

# %%
hotel['agent'].unique()
# Out:
# array([240., 242., 241.,  95., 250.,   6.,  nan, 253.,  36., 142.,  69.,
#        185., 328.,  96.,   8., 196.,   5., 360., 306., 314., 177., 251.,
#        273.,   9.,  14.,   7.,  27.,   1.,  11., 195.,  81.,  29.,  90.,
#         85.,  45., 152.,  19., 138., 129.,  83.,   2.,   3., 128., 150.,
#        191., 157.,  28.,  42.,  86.,  21., 234., 330.,  77.,  15., 229.,
#        495., 449.,  52.,  98., 423.])

# %%
hotel.isnull().sum()
# Out:
# hotel                                0
# is_canceled                          0
# lead_time                            0
# arrival_date_year                    0
# arrival_date_month                   0
# arrival_date_week_number             0
# arrival_date_day_of_month            0
# stays_in_weekend_nights              0
# stays_in_week_nights                 0
# adults                               0
# children                             0
# babies                               0
# meal                                 0
# country                              0
# market_segment                       0
# distribution_channel                 0
# is_repeated_guest                    0
# previous_cancellations               0
# previous_bookings_not_canceled       0
# reserved_room_type                   0
# assigned_room_type                   0
# booking_changes                      0
# deposit_type                         0
# agent                              127
# ...

# %% [markdown]
# # Task 1: Data Cleaning

# %%
hotel.fillna(hotel['agent'].mode()[0],inplace=True)

# %%
hotel.drop('company',axis=1,inplace=True)

# %%
hotel.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# # Task 2: Booking Pattern Analysis

# %%
hotel.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0         68               2015               July
# 1  Resort Hotel            0         14               2015               July
# 2  Resort Hotel            0         10               2015               July
# 3  Resort Hotel            0          9               2015               July
# 4  Resort Hotel            0         51               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          2
# 2                        27                          3
# 3                        27                          3
# 4                        28                          6
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     4       2  ...
# ...

# %%
fig, ax = plt.subplots(figsize = (8, 5))
sns.countplot(x = "arrival_date_year", data = hotel)
plt.show()

# %% [markdown]
# # Interpretation: Based on the dataset, it appears that the majority of customers arrived at the hotel in the year 2016. This suggests that 2016 was possibly a peak year for hotel arrivals.

# %%
sorted_hotel = hotel.loc[:, ['arrival_date_month']].sort_values(by='arrival_date_month', ascending=False)
fig, ax = plt.subplots(figsize = (8, 5))
sns.countplot(x = "arrival_date_month", data = sorted_hotel)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha = "right")
plt.show()

# %% [markdown]
# # Interpretation: Based on the dataset, it appears that the majority of customers arrived at the hotel in the month of May and August. This suggests that from the month of May to August is possibly the peak months for hotel arrivals.

# %%
sns.scatterplot(data=hotel, x='lead_time', y='is_canceled',hue='lead_time')
plt.xlabel('Lead Time')
plt.ylabel('Booking Cancellation (1=Cancelled, 0=Not Cancelled)')
plt.title('Relationship between Lead Time and Booking Cancellation')

plt.show()

# %% [markdown]
# # Interpretation: As we can see theres no direct relationship between leadtime and cancellation but where the lead time is above 400 days there is no chances of cancellation.

# %% [markdown]
# # Task 3: Booking Cancellation Analysis

# %%
fig, ax = plt.subplots(figsize = (8, 5))
ax.set_title('Count of arrival wise cancellation status')
sns.countplot(x = "arrival_date_month", data = hotel,hue='is_canceled')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha = "right")
plt.show()

# %% [markdown]
# # Interpretation: Between the month of May to August there have been high cancellations observed.

# %%
fig, ax = plt.subplots(figsize = (8, 5))
ax.set_title('Count of hotel wise cancellation status')
sns.countplot(x = "hotel", data = hotel,hue='is_canceled')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 40 , ha = "right")
plt.show()

# %% [markdown]
# # Interpretation: High cancellations have bee observed in city hotels which makes it the risky hotels to get assured booking.

# %%
fig, ax = plt.subplots(figsize = (8, 5))
ax.set_title('Count of days_in_waiting_list wise cancellation status')
sns.countplot( y='days_in_waiting_list',hue='is_canceled',data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: There is no direct relation between number of days waiting and cancellation.

# %% [markdown]
# # Task 4: Customer Behavioral Segmentation

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.histplot(x = hotel["lead_time"], hue = hotel["is_canceled"], ax = ax)
plt.show()

# %% [markdown]
# # Interpretation:  It appears that shorter lead times, indicating bookings made closer to the arrival date, are associated with a higher likelihood of not cancelling the hotel booking. This suggests that customers who book their stays closer to their planned arrival date are more committed to their reservation.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="total_of_special_requests", hue = "is_canceled", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: It appears that customers who make fewer special requests i.e, 0-2 are indeed more likely to cancel their hotel bookings.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="reserved_room_type", hue = "is_canceled", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: It appears that reserved room type A has that highest cancellation.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="customer_type", hue = "is_canceled", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: It appears that most of the customers are of type transient and has the highest cancellations.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="market_segment", hue = "customer_type", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: It appears that the majority on transient type customers prefer online TA of the market segment.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="customer_type", hue = "previous_cancellations", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: Most of the customers who cancelled previously belonged to transient type.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="customer_type", hue = "total_of_special_requests", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation : Most of the transient type customers has made 0 Special request and more than 1 special request.

# %% [markdown]
# # Part 2

# %% [markdown]
# #  Task 1: Revenue Management

# %%
hotel.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.lineplot(x = hotel['arrival_date_month'], y = hotel['adr'], ax = ax)
plt.show()

# %% [markdown]
# # Interpretation: It appears that in the month of August the average daily rate was all time high.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.histplot(x ="adr", hue = "assigned_room_type", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: It shows that majority of customers with assigned room type A has an average daily rate between 50 to 150.

# %% [markdown]
# # Task 2: Operational Efficiency

# %%
plt.figure(figsize=(8, 8))
percentage=hotel['distribution_channel'].value_counts()
label=list(hotel['distribution_channel'].value_counts().index)
plt.pie(percentage, labels=label, autopct='%0.2f%%',explode=[0.02,0.04,0.06,0.08])
plt.title('Percentage Distribution of Bookings by Distribution Channel')
plt.show()

# %% [markdown]
# # Interpretation: Travel Agents or tour operators has the highest portion of booking i.e, approximately 80%

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.histplot(x ="booking_changes", hue = "is_canceled", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: Most of the customers who made no changes has also cancelled the booking.

# %%
sns.scatterplot(data=hotel, x='days_in_waiting_list', y='is_canceled',hue='is_canceled')
plt.xlabel('Waiting time in days')
plt.ylabel('Booking Cancellation (1=Cancelled, 0=Not Cancelled)')
plt.title('Relationship between waiting time in days and Booking Cancellation')

plt.show()

# %% [markdown]
# # Interpretation: It appears that there is no correlation between waiting time in days and cancellation of bookings.

# %% [markdown]
# # Task 3: Loyalty Programs and Repeat Business

# %%
hotel.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="is_repeated_guest", hue = "reserved_room_type", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: Most of the customers who have visited for the first time were belong to 'A' reserved room type.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="is_repeated_guest", hue = "total_of_special_requests", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: It appears that most of the customers who have booked for the first time had no special request whereas the second highest of them had a single special request, approximately 40% of them had 2 special request and few had 3 special request.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.histplot(x ="lead_time", hue = "is_repeated_guest", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: Most of the customers booking for the first time had a lead time ranging in between 0 to 100 and very few were the existing guest with nominal lead time.

# %% [markdown]
# # Part 3

# %%
sns.scatterplot(data=hotel, x='total_of_special_requests', y='adr',hue='assigned_room_type')
plt.xlabel('total_of_special_requests')
plt.ylabel('Average daily rate')
plt.title('Relationship between special requests made and Average daily rate')

plt.show()

# %% [markdown]
# # Interpretation: It seems theres no such relation between average daily rate and the total special requests.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="customer_type", hue = "total_of_special_requests", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: Majority of customers with 0 or 1 special request belong to transient type.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="required_car_parking_spaces", hue = "total_of_special_requests", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: It can be seen that most of the customers with 0 or 1 special request require no car parking and only few of them had 1 special request of car parking.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.countplot(x ="deposit_type", hue = "total_of_special_requests", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: It appears that most of the customers with 0 or 1 special request had no deposit while booking.

# %% [markdown]
# # Task 2: Marketing and Sales Optimization

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.lineplot(x = hotel['market_segment'], y = hotel['adr'], ax = ax)
plt.show()

# %% [markdown]
# # Interpretation: It appears that direct market segement has the highest average daily rate.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.lineplot(x = hotel['distribution_channel'], y = hotel['adr'], ax = ax)
plt.show()

# %% [markdown]
# # Interpretation: It appears that in direct and GDS distribution channel the average daily rate is highest whereas for corporate distribution channel it is the lowest.

# %%
hotel.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.histplot(x ="adr", hue = "meal", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: Most of the customers who have an average daily rate between 50 to 100 has bed breakfast included in their package whereas the second highest count of customers  having an average daily rate between 90 - 100 have self catering meal type.

# %%
fig, ax = plt.subplots(figsize = (15, 7))
sns.histplot(x ="adr", hue = "total_of_special_requests", data=hotel)
plt.show()

# %% [markdown]
# # Interpretation: Most of the customers with an average daily rate between 60 to 130 have 0 or 1 special request and only nominal count of customers have 2 or 3 special request.

# %% [markdown]
# # Conclusion: The analysis of the hotel dataset reveals significant trends and patterns that can inform strategic decisions. 2016 emerges as a peak year for hotel arrivals, with May to August being the peak months. Lead time above 400 days indicates minimal chances of cancellation, while high cancellations are observed in city hotels during the peak months. Customers booking closer to their arrival date exhibit higher commitment, while fewer special requests are associated with higher cancellation rates. Room type A and transient customers show the highest cancellation rates, with insights into their preferences shedding light on cancellation probabilities. Moreover, the average daily rate peaks in August, with variations across different market segments and distribution channels. Understanding these dynamics is crucial for optimizing revenue and managing cancellation risks effectively.

# %% [markdown]
# # Final recommedation: Based on the insights gleaned from the comprehensive analysis of the hotel dataset, it is recommended that the hotel management focus on optimizing revenue and mitigating cancellation risks by implementing targeted strategies. This includes offering incentives for early bookings, especially during the peak months of May to August, and incentivizing guests to make reservations directly rather than through third-party channels, given the higher average daily rates associated with direct bookings. Additionally, efforts should be made to understand and cater to the preferences of transient guests, who exhibit the highest cancellation rates, by offering personalized experiences or packages tailored to their needs. Moreover, considering the correlation between shorter lead times and higher commitment to reservations, the hotel can explore dynamic pricing strategies to capitalize on last-minute bookings while minimizing the risk of cancellations. By leveraging these insights and implementing strategic initiatives, the hotel can enhance revenue generation and improve overall operational efficiency.
